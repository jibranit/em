# %% [markdown]
# # Investigate a TMDb movie Database

# %% [markdown]
# ## Introduction
#
# In this project we will be investigating a TMDb movies database file which has collection of important details of about 10k+ movies, including their details of budget, revenue, release dates, etc.
#
# Let's take a glimpse at TMDb movie database csv file...

# %%
import pandas as pd

#reading tmdb csv file and storing that to a variable
glimpse_tmdb = pd.read_csv('data.csv')

#calling out first 5 rows (excluding headers) of tmdb database
glimpse_tmdb.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline      ...       \
# 0              The park is open.      ...
# 1             What a Lovely Day.      ...
# 2     One Choice Can Destroy You      ...
# 3  Every generation has a story.      ...
# 4            Vengeance Hits Home      ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015       5292
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015       2947
#
#    vote_average  release_year   budget_adj   revenue_adj
# 0           6.5          2015  137999939.3  1.392446e+09
# 1           7.1          2015  137999939.3  3.481613e+08
# 2           6.3          2015  101199955.5  2.716190e+08
# 3           7.5          2015  183999919.0  1.902723e+09
# 4           7.3          2015  174799923.1  1.385749e+09
#
# [5 rows x 21 columns]

# %% [markdown]
# ### What can we say about the dataset provided?
# <ul>
#     <li>The columns *'budget', 'revenue', 'budget_adj', 'revenue_adj'* has not given us the currency but for this dataset we will assume that it is in dollars.</li>
#     <li>The vote count for each movie is not similar, for example, the movie *'Mad Max : Fury Road'* has *6k+* votes while *Sinister 2* has only *331 votes* (as seen above). Since the votes of the movies vary so much the *vote_average* column also is effected by it. So we cannot calculate or assume that movie with highest votes or rating was more successful since the voters of each film vary.</li>
# </ul>
#
# ### What Questions can be brainstormed?
# Looking at this database...
# <ul>
# <li>The first question comes in my mind is which movie gained the most profit or we can also kind of say that which movie has been the people's favourite?</li>
#
# <li>Since this is just the glimpse of the database, the glimpse of the data just shows the movies in the year 2015, but there are also other movies released in different years so the Second question comes in my mind is in which year the movies made the most profit?</li>
#
# <li>Finally my curious mind wanted to know what are the similar characteristics of movies which have gained highest profits?</li>
# </ul>
#
#
# ### Questions to be Answered
# <ol>
#     <li>General questions about the dataset.</li>
#         <ol type = 'a'>
#             <li>Which movie earns the most and least profit?</li>
#             <li>Which movie had the greatest and least runtime?</li>
#             <li>Which movie had the greatest and least budget?</li>
#             <li>Which movie had the greatest and least revenue?</li>
#             <li>What is the average runtime of all movies?</li>
#             <li>In which year we had the most movies making profits?</li>
#         </ol>
#     <li>What are the similar characteristics does the most profitable movie have?</li>
#         <ol type = 'a'>
#             <li>Average duration of movies.</li>
#             <li>Average Budget.</li>
#             <li>Average revenue.</li>
#             <li>Average profits.</li>
#             <li>Which director directed most films?</li>
#             <li>Whcih cast has appeared the most?</li>
#             <li>Which genre were more successful?</li>
#         </ol>
# </ol>
#
#
# -----
#
#
# ## Data Cleaning
#
# **Before answering the above questions we need a clean dataset which has columns and rows we need for calculations.**
#
# First, lets clean up the columns.
# We will only keep the columns we need and remove the rest of them.
#
# Columns to delete -  `id, imdb_id, popularity, budget_adj, revenue_adj, homepage, keywords, overview, production_companies, vote_count and vote_average.`
#
# **We have already cleaned the dataset for you**

# %%
#importing all the nescessory libraries we need for our analysis
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

#this variable will store the database of tmdb movies into a dataframe
movie_data = pd.read_csv('movie_data_clean.csv')
movie_data.head(3)
# Out:
#    budget_(in_US-Dollars)  revenue_(in_US-Dollars)  profit_(in_US_Dollars)  \
# 0               150000000               1513528810              1363528810
# 1               150000000                378436354               228436354
# 2               110000000                295238201               185238201
#
#        original_title                                               cast  \
# 0      Jurassic World  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Mad Max: Fury Road  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2           Insurgent  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#            director                     tagline  runtime  \
# 0   Colin Trevorrow           The park is open.      124
# 1     George Miller          What a Lovely Day.      120
# 2  Robert Schwentke  One Choice Can Destroy You      119
#
#                                       genres release_date  release_year
# 0  Action|Adventure|Science Fiction|Thriller   2015-06-09          2015
# 1  Action|Adventure|Science Fiction|Thriller   2015-05-13          2015
# 2         Adventure|Science Fiction|Thriller   2015-03-18          2015

# %%
movie_data.shape
# Out:
# (3854, 11)

# %%
movie_data[['original_title','profit_(in_US_Dollars)']].set_index('original_title').shape
# Out:
# (3854, 1)

# %%
'''
a = set(movie_data[['original_title','revenue_(in_US-Dollars)']].set_index('original_title').min())
for i in range(len(movie_data[['original_title','revenue_(in_US-Dollars)']].set_index('original_title'))):
    if movie_data[['original_title','revenue_(in_US-Dollars)']].set_index('original_title')[movie_data[['original_title','revenue_(in_US-Dollars)']].set_index('original_title') == a]:
        print('hi')'''
# Out:
# "\na = set(movie_data[['original_title','revenue_(in_US-Dollars)']].set_index('original_title').min())\nfor i in range(len(movie_data[['original_title','revenue_(in_US-Dollars)']].set_index('original_title'))):\n    if movie_data[['original_title','revenue_(in_US-Dollars)']].set_index('original_title')[movie_data[['original_title','revenue_(in_US-Dollars)']].set_index('original_title') == a]:\n        print('hi')"

# %%
#a = movie_data[['original_title','revenue_(in_US-Dollars)']].set_index('original_title')
#pd.value_counts(a['revenue_(in_US-Dollars)'].astype(int) == 2)

# %%
#for i in range(len(movie_data[['original_title','revenue_(in_US-Dollars)']].set_index('original_title'))):
 #   movie_data[['original_title','revenue_(in_US-Dollars)']].set_index('original_title').min()

# %%
#a = movie_data[['original_title','revenue_(in_US-Dollars)']].set_index('original_title').min().tolist()[0]
#movie_data[movie_data['revenue_(in_US-Dollars)'] == a]
#a = movie_data[['original_title','profit_(in_US_Dollars)']].set_index('original_title')
#c = a[a.values > 0].min().tolist()[0]
#movie_data[movie_data['profit_(in_US_Dollars)'] == c][['original_title','profit_(in_US_Dollars)']]

# %%
def maxmin(col):
    b = movie_data[['original_title',col]].set_index('original_title').max().tolist()[0]
    print('MOVIE WITH MAX',col,'IS:\n')
    print(movie_data[movie_data[col] == b][['original_title',col]].set_index('original_title'),' \n-------------------  ')
    a = movie_data[['original_title',col]].set_index('original_title')
    c = a[a.values > 0].min().tolist()[0]
    print('MOVIE WITH MIN',col,' IS:\n')
    print(movie_data[movie_data[col] == c][['original_title',col]])
    #print('Max value is',movie_data[['original_title',col]].set_index('original_title').idxmax().values.tolist()[0])
    #print('Min value is',movie_data[['original_title',col]].set_index('original_title').idxmin().values.tolist()[0])

# %% [markdown]
# **Now let's dig deep and answer the questions!**
#
# ### Q1. 1A Which movie earns the most and least profit?

# %%
maxmin('profit_(in_US_Dollars)')
# Out:
# MOVIE WITH MAX profit_(in_US_Dollars) IS:
#
#                 profit_(in_US_Dollars)
# original_title
# Avatar                      2544505847
# -------------------
# MOVIE WITH MIN profit_(in_US_Dollars)  IS:
#
#      original_title  profit_(in_US_Dollars)
# 2028   Hross Ã­ oss                       1

# %% [markdown]
# ### 1B Which movie had the greatest and least runtime?

# %%
maxmin('runtime')
# Out:
# MOVIE WITH MAX runtime IS:
#
#                 runtime
# original_title
# Carlos              338
# -------------------
# MOVIE WITH MIN runtime  IS:
#
#      original_title  runtime
# 1758    Kid's Story       15

# %% [markdown]
# ### 1C Which movie had the greatest and least budget?

# %%
maxmin('budget_(in_US-Dollars)')
# Out:
# MOVIE WITH MAX budget_(in_US-Dollars) IS:
#
#                    budget_(in_US-Dollars)
# original_title
# The Warrior's Way               425000000
# -------------------
# MOVIE WITH MIN budget_(in_US-Dollars)  IS:
#
#                original_title  budget_(in_US-Dollars)
# 810              Lost & Found                       1
# 1251  Love, Wedding, Marriage                       1

# %% [markdown]
# ### 1D Which movie had the greatest and least revenue?

# %%
maxmin('revenue_(in_US-Dollars)')
# Out:
# MOVIE WITH MAX revenue_(in_US-Dollars) IS:
#
#                 revenue_(in_US-Dollars)
# original_title
# Avatar                       2781505847
# -------------------
# MOVIE WITH MIN revenue_(in_US-Dollars)  IS:
#
#        original_title  revenue_(in_US-Dollars)
# 1732  Shattered Glass                        2
# 2897         Mallrats                        2

# %% [markdown]
# ### 1E What is the average runtime of all movies?

# %%
movie_data['runtime'].mean()
# Out:
# 109.22029060716139

# %% [markdown]
# ### 1F In which year we had the most movies making profits?

# %%
#movie_data['profit_(in_US_Dollars)'] = movie_data[movie_data['profit_(in_US_Dollars)'] > 0]

# %%
#movie_data.groupby('release_year')['profit_(in_US_Dollars)'].sum()#.filter(lambda x: x > 0)

# %%
#movie_data['profit_(in_US_Dollars)'] = movie_data[movie_data['profit_(in_US_Dollars)'] > 0]
#a = movie_data.groupby('release_year')['profit_(in_US_Dollars)']
#a[a['profit_(in_US_Dollars)'] > 0]

# %%
movie = movie_data[movie_data['profit_(in_US_Dollars)'] > 0]
pd.value_counts(movie_data['release_year']).head(1)
# Out:
# 2011    199
# Name: release_year, dtype: int64

# %%
movie_data.shape
# Out:
# (3854, 11)

# %%
movie.shape
# Out:
# (2778, 11)

# %% [markdown]
# ### Q2. 2A Average runtime of movies

# %%
movie_data['runtime'].mean()
# Out:
# 109.22029060716139

# %% [markdown]
# ### 2B Average Budget of Movies

# %%
movie_data['budget_(in_US-Dollars)'].mean()
# Out:
# 37203696.954852104

# %% [markdown]
# ### 2C Average Revenue of Movies

# %%
movie_data['revenue_(in_US-Dollars)'].mean()
# Out:
# 107686616.09807992

# %% [markdown]
# ### 2D Average Profit of Movies

# %%
movie['profit_(in_US_Dollars)'].mean()
# Out:
# 103244454.42584594

# %% [markdown]
# ### 2E Which directer directed most films?

# %%
pd.value_counts(movie_data['director']).head(1)
# Out:
# Steven Spielberg    27
# Name: director, dtype: int64

# %% [markdown]
# ### 2F Which cast has appeared the most?

# %%
a = movie_data['cast'].str.cat(sep='|').split('|')
b = pd.Series(a)
pd.value_counts(b).sort_values(ascending = False).head(1)
#pd.DataFrame.from_dict(a, orient = 'index')
# Out:
# Robert De Niro    52
# dtype: int64

# %% [markdown]
# ### 2G Which genre were more successful?

# %%
movie_data.groupby('genres')['profit_(in_US_Dollars)'].sum()
# Out:
# genres
# Action                                                 1108505513
# Action|Adventure                                        161160439
# Action|Adventure|Animation|Family|Fantasy               424987477
# Action|Adventure|Animation|Family|Science Fiction       539442092
# Action|Adventure|Animation|Science Fiction                1731128
# Action|Adventure|Animation|Science Fiction|Thriller      18428063
# Action|Adventure|Comedy                                 227434058
# Action|Adventure|Comedy|Crime                           209167176
# Action|Adventure|Comedy|Crime|Drama                     158701578
# Action|Adventure|Comedy|Crime|Thriller                  365612056
# Action|Adventure|Comedy|Drama                            15754284
# Action|Adventure|Comedy|Drama|Family                     49141030
# Action|Adventure|Comedy|Drama|Mystery                   -10730514
# Action|Adventure|Comedy|Drama|Science Fiction            35479424
# Action|Adventure|Comedy|Drama|Western                    98033791
# Action|Adventure|Comedy|Family                          281803333
# Action|Adventure|Comedy|Family|Fantasy                  435764499
# Action|Adventure|Comedy|Family|Science Fiction          159011982
# Action|Adventure|Comedy|Family|Thriller                   -906293
# Action|Adventure|Comedy|Romance                         242345438
# Action|Adventure|Comedy|Science Fiction                 902106419
# Action|Adventure|Comedy|Thriller                         -5772510
# Action|Adventure|Comedy|Thriller|Crime                  -43279825
# Action|Adventure|Comedy|Western                          38323487
# Action|Adventure|Crime                                  628184356
# Action|Adventure|Crime|Drama                             11480851
# Action|Adventure|Crime|Drama|Fantasy                     -3189887
# Action|Adventure|Crime|Drama|Mystery                     -5452319
# Action|Adventure|Crime|Drama|Romance                     -7505520
# Action|Adventure|Crime|Drama|Thriller                   -23276567
#                                                           ...
# Thriller|Science Fiction|Action|Crime                    74646581
# Thriller|Science Fiction|Adventure|Action               -74010360
# Thriller|Science Fiction|Drama                           -7919749
# Thriller|Science Fiction|Drama|Mystery                    3039258
# Thriller|Science Fiction|Mystery                        328244590
# Thriller|Science Fiction|Mystery|Romance                -23467223
# War                                                      35804635
# War|Action                                              521636941
# War|Action|Thriller|Science Fiction                     -20193217
# War|Adventure|Drama                                     322409852
# War|Adventure|Drama|Romance                             -25117355
# War|Adventure|Science Fiction                           490523427
# War|Crime|Drama|Mystery|Romance                         -26085092
# War|Drama                                               -15045935
# War|Drama|Action                                        143817906
# War|Drama|History                                        -3799460
# War|Drama|History|Action                                 84984035
# War|Drama|Romance                                         4278575
# War|History|Action|Adventure|Drama                       12298192
# Western                                                 216269960
# Western|Action                                           -1700000
# Western|Action|Adventure|Drama                           35000000
# Western|Adventure                                         8103450
# Western|Animation|Adventure|Comedy|Family                42563539
# Western|Animation|Family|Comedy|Music                    -6048539
# Western|Drama                                           -30373704
# Western|Drama|Adventure|Thriller                        397950503
# Western|History                                           5795189
# Western|History|War                                    -119180039
# Western|Thriller                                         -6993853
# Name: profit_(in_US_Dollars), Length: 1053, dtype: int64

# %%
movie_data
# Out:
#       budget_(in_US-Dollars)  revenue_(in_US-Dollars)  profit_(in_US_Dollars)  \
# 0                  150000000               1513528810              1363528810
# 1                  150000000                378436354               228436354
# 2                  110000000                295238201               185238201
# 3                  200000000               2068178225              1868178225
# 4                  190000000               1506249360              1316249360
# 5                  135000000                532950503               397950503
# 6                  155000000                440603537               285603537
# 7                  108000000                595380321               487380321
# 8                   74000000               1156730962              1082730962
# 9                  175000000                853708609               678708609
# 10                 245000000                880674609               635674609
# 11                 176000003                183987723                 7987720
# 12                  15000000                 36869414                21869414
# 13                  88000000                243637091               155637091
# 14                 280000000               1405035767              1125035767
# 15                  44000000                155760117               111760117
# 16                  48000000                325771424               277771424
# 17                 130000000                518602163               388602163
# 3844  Kris Kristofferson|Ali MacGraw|Ernest Borgnine...
# 3845  Donald Sutherland|Brooke Adams|Leonard Nimoy|V...
# 3846  Diana Ross|Michael Jackson|Nipsey Russell|Ted ...
# 3847  William Holden|Lee Grant|Jonathan Scott-Taylor...
# 3848  John Hurt|Richard Briers|Michael Graham Cox|Jo...
# 3849  Elizabeth Taylor|Richard Burton|George Segal|S...
# 3850  Paul Newman|Julie Andrews|Lila Kedrova|HansjÃ¶...
# 3851  John Wayne|Robert Mitchum|James Caan|Charlene ...
# 3852  Steve McQueen|Richard Attenborough|Richard Cre...
# 3853  Stephen Boyd|Raquel Welch|Edmond O'Brien|Donal...
#
#                             director  \
# 0                    Colin Trevorrow
# 1                      George Miller
# 2                   Robert Schwentke
# 3                        J.J. Abrams
# 4                          James Wan
# 5     Alejandro GonzÃ¡lez IÃ±Ã¡rritu
# 6                        Alan Taylor
# 7                       Ridley Scott
# 8           Kyle Balda|Pierre Coffin
# 9                        Pete Docter
# 10                        Sam Mendes
# 11    Lana Wachowski|Lilly Wachowski
# 12                      Alex Garland
# 13                    Chris Columbus
# 14                       Joss Whedon
# 15                 Quentin Tarantino
# 16                   Olivier Megaton
# 17                       Peyton Reed
# 18                   Kenneth Branagh
# 19                  Francis Lawrence
# 20                         Brad Bird
# 21                     Antoine Fuqua
# 22                       Brad Peyton
# 23                Sam Taylor-Johnson
# 24                        Adam McKay
# 25             Christopher McQuarrie
# 26                   Seth MacFarlane
# 27                    Matthew Vaughn
# 28                      Tom McCarthy
# 29                          Wes Ball
# ...                              ...
# 3824                     Robert Wise
# 3825                      David Lean
# 3826                     Ken Annakin
# 3827                  George Stevens
# 3828                   Peter R. Hunt
# 3829                 George Roy Hill
# 3830                John Schlesinger
# 3831                   Sam Peckinpah
# 3832                  Randal Kleiser
# 3833                  Jeannot Szwarc
# 3834                George A. Romero
# 3835                  Richard Donner
# 3836                  John Carpenter
# 3837                     John Landis
# 3838                  Michael Cimino
# 3839                     Alan Parker
# 3840                    Ralph Bakshi
# 3841                 John Guillermin
# 3842                  Norman Jewison
# 3843                    Guy Hamilton
# 3844                   Sam Peckinpah
# 3845                  Philip Kaufman
# 3846                    Sidney Lumet
# 3847          Don Taylor|Mike Hodges
# 3848                    Martin Rosen
# 3849                    Mike Nichols
# 3850                Alfred Hitchcock
# 3851                    Howard Hawks
# 3852                     Robert Wise
# 3853               Richard Fleischer
#
#                                                 tagline  runtime  \
# 0                                     The park is open.      124
# 1                                    What a Lovely Day.      120
# 2                            One Choice Can Destroy You      119
# 3                         Every generation has a story.      136
# 4                                   Vengeance Hits Home      137
# 5       (n. One who has returned, as if from the dead.)      156
# 6                                      Reset the future      125
# 7                                        Bring Him Home      141
# 8          Before Gru, they had a history of bad bosses       91
# 9              Meet the little voices inside your head.       94
# 10                                A Plan No One Escapes      148
# 11                                Expand your universe.      124
# 12    There is nothing more human than the will to s...      108
# 13                                             Game On.      105
# 14                                  A New Age Has Come.      141
# 15     No one comes up here without a damn good reason.      167
# 16                                         It Ends Here      109
# 17                          Heroes Don't Get Any Bigger      115
# 18                      Midnight is just the beginning.      112
# 19                          The fire will burn forever.      136
# 20         Imagine a world where nothing is impossible.      130
# 21                                     Believe in Hope.      123
# 22    A rescue pilot survived an earthquake, this is...      114
# 23                                     Are you curious?      125
# 24                                This is a true story.      130
# 25                 Desperate Times. Desperate Measures.      131
# 26                                Ted is Coming, Again.      115
# 27                                  Manners maketh man.      130
# 28                  Break the story. Break the silence.      128
# 29                     The Maze Was Just the Beginning.      132
# ...                                                 ...      ...
# 3824               The happiest sound in all the world!      174
# 3825  Turbulent were the times and fiery was the lov...      197
# 3826  or How I Flew from London to Paris in 25 hours...      138
# 3827                                                NaN      199
# 3828  Far up! Far out! Far more! James Bond 007 is b...      142
# 3829       Not that it matters, but most of it is true.      110
# 3830   Whatever you hear about Midnight Cowboy is true.      113
# 3831  If you only want to spend two hours in a movie...      145
# 3832                                 Grease is the word      110
# 3833  Just when you thought it was safe to go back i...      116
# 3834  When there's no more room in hell, the dead wi...      127
# 3835                      You'll Believe a Man Can Fly!      143
# 3836                            The Night HE Came Home!       91
# 3837  It was the Deltas against the rules... the rul...      109
# 3838  One of the most important and powerful films o...      183
# 3839  Walk into the incredible true experience of Bi...      121
# 3840                  Fantasy...beyond your imagination      132
# 3841  A murderer strikes on board the luxury Nile st...      140
# 3842                                                NaN      145
# 3843                                                NaN      118
# 3844  Kristofferson and MacGraw...ain't nothin' gonn...      110
# 3845  From deep space... The seed is planted... the ...      115
# 3846  From the book that's an American traditionâ€¦ ...      134
# 3847                 The first time was only a warning.      107
# 3848  All the world will be your enemy, Prince with ...       88
# 3849  You are cordially invited to George and Martha...      131
# 3850                  It tears you apart with suspense!      128
# 3851                  It's the Big One with the Big Two      120
# 3852  This is the heroic story of the men on the U.S...      182
# 3853  A Fantastic and Spectacular Voyage... Through ...      100
#
#                                                genres release_date  \
# 0           Action|Adventure|Science Fiction|Thriller   2015-06-09
# 1           Action|Adventure|Science Fiction|Thriller   2015-05-13
# 2                  Adventure|Science Fiction|Thriller   2015-03-18
# 3            Action|Adventure|Science Fiction|Fantasy   2015-12-15
# 4                               Action|Crime|Thriller   2015-04-01
# 5                    Western|Drama|Adventure|Thriller   2015-12-25
# 6           Science Fiction|Action|Thriller|Adventure   2015-06-23
# 7                     Drama|Adventure|Science Fiction   2015-09-30
# 8                   Family|Animation|Adventure|Comedy   2015-06-17
# 9                             Comedy|Animation|Family   2015-06-09
# 10                             Action|Adventure|Crime   2015-10-26
# 11           Science Fiction|Fantasy|Action|Adventure   2015-02-04
# 12                              Drama|Science Fiction   2015-01-21
# 13                      Action|Comedy|Science Fiction   2015-07-16
# 14                   Action|Adventure|Science Fiction   2015-04-22
# 15                        Crime|Drama|Mystery|Western   2015-12-25
# 16                              Crime|Action|Thriller   2015-01-01
# 17                   Science Fiction|Action|Adventure   2015-07-14
# 18                       Romance|Fantasy|Family|Drama   2015-03-12
# 19                      War|Adventure|Science Fiction   2015-11-18
# 20    Action|Family|Science Fiction|Adventure|Mystery   2015-05-19
# 21                                       Action|Drama   2015-06-15
# 22                              Action|Drama|Thriller   2015-05-27
# 23                                      Drama|Romance   2015-02-11
# 24                                       Comedy|Drama   2015-12-11
# 25                                             Action   2015-07-23
# 26                                             Comedy   2015-06-25
# 27                      Crime|Comedy|Action|Adventure   2015-01-24
# 28                             Drama|Thriller|History   2015-11-06
# 29                    Action|Science Fiction|Thriller   2015-09-09
# ...                                               ...          ...
# 3824                       Drama|Family|Music|Romance   1965-03-02
# 3825                                Drama|Romance|War   1965-12-22
# 3826                          Action|Adventure|Comedy   1965-06-03
# 3827                                    Drama|History   1965-02-15
# 3828                        Adventure|Action|Thriller   1969-12-12
# 3829                      History|Drama|Western|Crime   1969-09-23
# 3830                                            Drama   1969-05-25
# 3831                                Adventure|Western   1969-06-17
# 3832                                            Music   1978-07-07
# 3833                                  Horror|Thriller   1978-06-16
# 3834                                           Horror   1978-09-02
# 3835         Adventure|Fantasy|Action|Science Fiction   1978-12-14
# 3836                                  Horror|Thriller   1978-10-25
# 3837                                           Comedy   1978-07-27
# 3838                                        Drama|War   1978-12-08
# 3839                                      Drama|Crime   1978-10-06
# 3840                        Drama|Animation|Adventure   1978-11-15
# 3841                                          Mystery   1978-10-06
# 3842                                     Drama|Action   1978-04-26
# 3843                    Action|Adventure|War|Thriller   1978-11-01
# 3844                              Action|Comedy|Drama   1978-06-27
# 3845          Horror|Thriller|Science Fiction|Mystery   1978-12-19
# 3846   Adventure|Family|Fantasy|Music|Science Fiction   1978-10-24
# 3847                     Action|Drama|Horror|Thriller   1978-06-09
# 3848                        Adventure|Animation|Drama   1978-10-14
# 3849                                            Drama   1966-06-21
# 3850                                 Mystery|Thriller   1966-07-13
# 3851                                   Action|Western   1966-12-17
# 3852               Action|Adventure|Drama|War|Romance   1966-12-20
# 3853                        Adventure|Science Fiction   1966-08-24
#
#       release_year
# 0             2015
# 1             2015
# 2             2015
# 3             2015
# 4             2015
# 5             2015
# 6             2015
# 7             2015
# 8             2015
# 9             2015
# 10            2015
# 11            2015
# 12            2015
# 13            2015
# 14            2015
# 15            2015
# 16            2015
# 17            2015
# 18            2015
# 19            2015
# 20            2015
# 21            2015
# 22            2015
# 23            2015
# 24            2015
# 25            2015
# 26            2015
# 27            2015
# 28            2015
# 29            2015
# ...            ...
# 3824          1965
# 3825          1965
# 3826          1965
# 3827          1965
# 3828          1969
# 3829          1969
# 3830          1969
# 3831          1969
# 3832          1978
# 3833          1978
# 3834          1978
# 3835          1978
# 3836          1978
# 3837          1978
# 3838          1978
# 3839          1978
# 3840          1978
# 3841          1978
# 3842          1978
# 3843          1978
# 3844          1978
# 3845          1978
# 3846          1978
# 3847          1978
# 3848          1978
# 3849          1966
# 3850          1966
# 3851          1966
# 3852          1966
# 3853          1966
#
# [3854 rows x 11 columns]

# %%
#filter  iteration
